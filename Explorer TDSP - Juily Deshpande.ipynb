# %% [markdown]
# # 🚗 **Welcome to the <font color='crimson'>** **Explorer Transportation Data Science Project! 🚗**</font>
#  Hosted by the [Northeast Big Data Innovation Hub](https://nebigdatahub.org/about) & [National Student Data Corps](https://nebigdatahub.org/nsdc), in collaboration with the [U.S. Department of Transportation Federal Highway Administration](https://highways.dot.gov/).
#
#
# ---

# %% [markdown]
# ## <font color='crimson'>**Project Information and Background:**</font>

# %% [markdown]
# **Project Description:**
#
# By participating in this project, you are joining a
# community of transportation data science learners interested in making roads safer for vulnerable road users.
#
# The Explorer TDSP has six Milestones, including guided transportation research into a community of interest. Each Milestone can take 1-5 hours, or less, depending on your level of experience.
#
# To learn more about this project, including key highlights, incentives, and important links, [review the TDSP Webpage here](https://nebigdatahub.org/nsdc/tdsp/)!

# %% [markdown]
# ## <font color='crimson'>**How to Get Started:**</font>

# %% [markdown]
# In order to work within this Google Colab Notebook, **please start by clicking on "File" in the top left corner of your notebook, and then "Save a copy in Drive." Rename the file to "Explorer TDSP - Your Full Name."** This will save a copy of the notebook in your personal Google Drive.
#
# You may now begin!

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## <font color='crimson'>**A Quick Introduction to Google Colab**</font>

# %% [markdown]
# Read below for a Google Colab QuickStart:
# - Google Colab is a Python Notebook environment built by Google that's free for all.
# - Colab Notebooks are made up of cells; cells can be either *text* or *code* cells. You can click the +code or +text button at the top of the Notebook to create a new cell.
# - Text cells use a format called [Markdown](https://www.markdownguide.org/getting-started/). Knowledge of Markdown is not required for this project. However, if you'd like to learn more, [check out this Cheatsheet!](https://www.markdownguide.org/cheat-sheet/)
# - Python code is executed in *code* cells. When you want to run your code, hover your cursor over the square brackets in the top left corner of your code cell. You'll notice a play button pop up! (▶) Click the play button to run the code in that cell. Code cells run one at a time.
# - The memory shared across your notebook is called the *Runtime*. You can think of a Runtime as a "code session" where everything you create and execute is temporarily stored.
# - Runtimes will persist for a short period of time, so you are safe if you need to refresh the page, but Google will shutdown a Runtime after enough time has passed. Everything that you have printed out will remain within your Notebook even if the runtime is disconnected.
#
# If this is your first time using Google Colab, we highly recommend reviewing the [NSDC's *Using Google Colab Guide*](https://nebigdatahub.org/wp-content/uploads/2023/04/NSDC-Data-Science-Projects-Introduction-Using-Google-Colab.pdf) before continuing. For a more comprehensive guide, see [Colab's *Welcome To Colaboratory* walkthrough.](https://colab.research.google.com/github/prites18/NoteNote/blob/master/Welcome_To_Colaboratory.ipynb)

# %% [markdown]
# ## <font color='crimson'>**An Introduction to Python Programming**</font>

# %% [markdown]
# Python is a programming language often used to analyze data.
#
# Python is open-source, which means it's free to use and distribute, even for commercial purposes. Python's versatility allows it to be used for web development, data visualization, artificial intelligence, scientific computing, and more.
#
# Python's extensive standard library, along with its powerful third-party packages, enable developers and data scientists to perform a vast array of tasks.
#
# For those looking to dive deeper into Python, here are some valuable resources:
# - [The Official Python Documentation](https://docs.python.org/3/) – Offers comprehensive guides and reference materials for Python leaners.
# - [Real Python](https://realpython.com/) – Provides tutorials and articles for Python developers of all skill levels.
# - [PyCon](https://pycon.org/) – The largest annual gathering for the Python community, which is useful for learning from experts and discovering the latest developments in the Python ecosystem.
# - [Python for Everybody](https://www.py4e.com/) – A book and website by Dr. Charles Severance that offers a free course on Python for beginners.

# %% [markdown]
# **Let's review some essential Python Functions!**
#
# Here are some key functions you'll frequently encounter:
#
# 1. **`head()`**: This function is crucial for getting a quick overview of your dataset. By default, it returns the first five rows, offering a snapshot of your data's structure and values.
#
# 2. **`describe()`**: This provides a summary of the statistical characteristics of your dataset. It's particularly useful for gaining insights into the distribution, mean, standard deviation, and range of numerical columns.
#
# 3. **`sum()`**: This calculates the total sum of a column or a series of numbers, proving essential for quick calculations and aggregations in data analysis.
#
# 4. **`isnull()`**: This helps identify missing or null values in your dataset, allowing for effective data cleaning and preprocessing.
#
# 5. **`value_counts()`**: Understanding the frequency of various values in your dataset is a common task in data science. The `value_counts()` function makes this easy by counting the occurrence of each unique value in a column.
#
# Now that you've reviewed these important concepts, let's dive in to the project!

# %% [markdown]
# ## <font color='crimson'>**Milestone #1 - Data Preparation**</font>
# GOAL: The main goal of this milestone is to set up your environment, install the required packages, learn how to access data and do some basic exploratory data analysis.

# %% [markdown]
# **Step 1:** Setting up libraries and installing packages
#
# A **library** is a collection of code that you can use in your programs, while a **package** is a folder that contains libraries or other packages, organized for easy use.
#
# To install a library, we'll use the following format:
# ```python
#  import <library name> as <shortname>
# ```
# We use a *short name* since it is easier to refer to the package to access functions and also to refer to subpackages within the library. Think of it as a nickname for easier reference!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %% [markdown]
# These are the libraries that will help us throughout this project. We invite you to research each library for a better understanding.
#
# We encourage you to read more about the important and most commonly used libraries like Pandas, Matplotlib, and Seaborn and write a few lines in your own words about what they do. [You may use the Data Science Resource Repository (DSRR) to find resources to get started!](https://nebigdatahub.org/nsdc/data-science-resource-repository/)

# %% [markdown]
# **TO DO:** Write a few lines about what each library does:
#
#
#
#
# > * Pandas: Pandas is a python library for data analysis. It provides easy-to-use data structures for data analysis. Handling missing data, insertion, deletion, grouping, slicing, etc of data can be done very easily and efficiently using Pandas. We often see data used for Data Science projects stored, viewed and manipulated using pandas data frames.
# > * Matplotlib: Matplotlib is a plotting libraryfor python which enables us to visualize our data, as well as our resuls. As the name suggests, this library allows us to plot graphs for easier understanding of trends in any data/result.
# > * Seaborn: Seaborn is a Python data visualization library based on matplotlib which excels in statistical visualization and aesthetics. Seaborn does the same work as Matplotlib but offers more advanced statistical visualizations with less code.

# %% [markdown]
# **Step 2:** Let’s access our data. We will be using the [NYC OpenData Motor Vehicle Collisions - Crashes dataset](https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Crashes/h9gi-nx95). According to NYC Open Data, "each row represents a crash event. The Motor Vehicle Collisions data tables contain information from all police reported motor vehicle collisions in NYC." If you need a reminder on how to upload your dataset, [please review helpful hints here.](https://nebigdatahub.org/wp-content/uploads/2023/04/NSDC-Data-Science-Projects-Introduction-Using-Google-Colab.pdf)
#
# Since this is a large dataset, we highly recommend that you upload your data by [mounting your Google Drive](https://colab.research.google.com/notebooks/io.ipynb#scrollTo=u22w3BFiOveA).
#
# To mount your Google Drive, begin by finding the folder icon on the left side of your screen. When you click on this folder icon, you will open the Files window. Click on the icon at the top of the Files window that says "Mount Drive" as you hover over it.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Next, we will read the data using the `pd.read_csv` function.
# Ensure that you've downloaded the dataset from NYC OpenData, and uploaded the dataset to your Google Drive.

# %% [markdown]
# Hint: Your data's file path describes the location of where your data lives. To locate your data's file path, click on the folder/file-shaped icon on the left side of the Notebook. You'll notice a folder labeled "drive." Search for your Motor Vehicle Collisions Dataset within that folder. Right click on your Dataset to "copy path." Paste that path below.

# %%
# TODO: Read the data using pandas read_csv function
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/NYC Collision Data Analysis/Motor_Vehicle_Collisions_-_Crashes_20241204.csv")
# Out:
# <ipython-input-6-9a7c4b8e54e9>:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/NYC Collision Data Analysis/Motor_Vehicle_Collisions_-_Crashes_20241204.csv")

# %% [markdown]
# **Step 3:** Let's see what the data looks like. We can use the `head` function which returns the first 5 rows of the dataset.

# %%
# TODO: Print the first 5 rows of the data using head function of pandas
data.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                      NaN  ...                    Unspecified
# 1                      NaN  ...                            NaN
# 2                      NaN  ...                    Unspecified
# 3  1211      LORING AVENUE  ...                            NaN
# 4                      NaN  ...                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  VEHICLE TYPE CODE 1  \
# 0                            NaN       4455765                Sedan
# 1                            NaN       4513547                Sedan
# 2                            NaN       4541903                Sedan
# 3                            NaN       4456314                Sedan
# 4                            NaN       4486609                  NaN
#
#    VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4  \
# 0                Sedan                  NaN                 NaN
# 1                  NaN                  NaN                 NaN
# 2        Pick-up Truck                  NaN                 NaN
# 3                  NaN                  NaN                 NaN
# 4                  NaN                  NaN                 NaN
#
#   VEHICLE TYPE CODE 5
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 29 columns]

# %%
# TODO: Describe the data using the describe function of pandas
desc_stats = data.describe()
desc_stats
# Out:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  1.437556e+06  1.437556e+06               1.474989e+06
# mean   4.062311e+01 -7.374050e+01               3.017372e-01
# std    2.012455e+00  3.651208e+00               6.758415e-01
# min    0.000000e+00 -7.425496e+01               0.000000e+00
# 25%    4.066674e+01 -7.397623e+01               0.000000e+00
# 50%    4.071872e+01 -7.392903e+01               0.000000e+00
# 75%    4.076651e+01 -7.387058e+01               0.000000e+00
# max    4.112615e+01  0.000000e+00               4.300000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              1.474977e+06                   1.475000e+06
# mean               1.331546e-03                   6.692881e-02
# std                3.845685e-02                   2.641120e-01
# min                0.000000e+00                   0.000000e+00
# 25%                0.000000e+00                   0.000000e+00
# 50%                0.000000e+00                   0.000000e+00
# 75%                0.000000e+00                   0.000000e+00
# max                8.000000e+00                   2.700000e+01
#
#        NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# count                  1.475000e+06               1.475000e+06
# mean                   7.315254e-04               3.137627e-02
# std                    2.777893e-02               1.762970e-01
# min                    0.000000e+00               0.000000e+00
# 25%                    0.000000e+00               0.000000e+00
# 50%                    0.000000e+00               0.000000e+00
# 75%                    0.000000e+00               0.000000e+00
# max                    6.000000e+00               4.000000e+00
#
#        NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  \
# count              1.475000e+06                1.475000e+06
# mean               1.254237e-04                1.988936e-01
# std                1.125895e-02                6.254595e-01
# min                0.000000e+00                0.000000e+00
# 25%                0.000000e+00                0.000000e+00
# 50%                0.000000e+00                0.000000e+00
# 75%                0.000000e+00                0.000000e+00
# max                2.000000e+00                4.300000e+01
#
#        NUMBER OF MOTORIST KILLED  COLLISION_ID  TOTAL_PEDESTRIANS_INVOLVED
# count               1.475000e+06  1.475000e+06                1.475000e+06
# mean                4.494915e-04  3.042294e+06                6.766034e-02
# std                 2.297681e-02  1.626833e+06                2.659943e-01
# min                 0.000000e+00  2.200000e+01                0.000000e+00
# 25%                 0.000000e+00  2.823271e+06                0.000000e+00
# 50%                 0.000000e+00  3.642504e+06                0.000000e+00
# 75%                 0.000000e+00  4.222781e+06                0.000000e+00
# max                 5.000000e+00  4.775840e+06                2.800000e+01

# %% [markdown]
# The information above is currently formatted in scientific notation. Need a refresher? [Review how to analyze and convert to and from scientific notation here!](https://www.mathsisfun.com/numbers/scientific-notation.html)
#
# 1. Latitude & Longitude: The latitude and longitude indicate where the crashes are occurring. However, there are some data points with latitude and longitude values of 0, which is likely due to missing or inaccurate data.
#
# 2. Number of Persons Injured: On average, each crash has around 0.305 injuries. The maximum number of injuries in a single crash is 43.
#
# 3. Number of Persons Killed: Fatalities are rare, with an average of 0.00146 deaths per crash. The maximum number of deaths in one crash is 8.
#
# 4. Number of Pedestrians, Cyclists, and Motorists Injured/Killed: These columns provide a breakdown of the injuries and fatalities by type of individual involved.
#
# 5. Collision ID: This is a unique identifier for each crash.
#
# **Self Notes:**
#
# *6E+5 is the same as 6 × 10^5*
#
# *3.12E4 is the same as 3.12 × 10^4*

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'> **Milestone #2 - Data Ethics, Pre-Processing, and Exploration** </font>
# GOAL: The main goal of this milestone is to assess the dataset, find missing values, and decide what to do with those missing data points.

# %% [markdown]
# **Step 1:**
# Before we begin assessing our data for missing values, it is important that we understand the ethical implications surrounding data processing. To best prepare yourself for this module, review one or more of the following resources:
# - [Data Science Ethics Flashcard Video Series](https://youtube.com/playlist?list=PLNs9ZO9jGtUB7XTjXy-ttoo2QSLld9SrV&feature=shared)
# - [What Do I Need to Understand about Data Ethics?](https://www.youtube.com/watch?v=Efy8htCDueE)
# -[Introduction to Data Cleaning](https://www.youtube.com/watch?v=t8WkoGLkdTk)
#
# **TO DO:** Based on the resources above and outside knowledge, what are some potential bias issues related to the availability of data from well-resourced communities as compared to under-resourced communities? How might bias show up in our dataset?
#
# > Answer here:
# - Data from well resourced community might be more structured hence possible to be incorporated.
# - There might be more missing values in under-resourced communities' data which would lead to those rows being dropped in many of the analysis tasks.
# - Bias might show up in our dataset in cases where there was no one to report a crash for example in remote or rural places; or data is incomplete; or in case of less literate people who don't know about informing when a traffic incident occurs.

# %% [markdown]
# **Step 2:**
# Check the dataset for missing values.

# %%
#TODO: Leverage the isnull() and sum() functions to find the number of missing values in each column
missing_values = data.isnull().sum()

#TODO: Turn the missing value counts into percentages
missing_values_percentage = (missing_values / len(data)) * 100

#TODO: Return counts and percentages of missing values in each column
missing_data = pd.DataFrame({'Missing Values': missing_values, 'Percentage (%)': missing_values_percentage})
missing_data.sort_values(by='Percentage (%)', ascending=False)
# Out:
#                                Missing Values  Percentage (%)
# VEHICLE TYPE CODE 5                   2129794       99.567378
# CONTRIBUTING FACTOR VEHICLE 5         2129500       99.553633
# VEHICLE TYPE CODE 4                   2105307       98.422616
# CONTRIBUTING FACTOR VEHICLE 4         2104055       98.364085
# VEHICLE TYPE CODE 3                   1990930       93.075518
# CONTRIBUTING FACTOR VEHICLE 3         1985155       92.805538
# OFF STREET NAME                       1772675       82.872147
# CROSS STREET NAME                      815476       38.123315
# ZIP CODE                               664310       31.056339
# BOROUGH                                664048       31.044091
# ON STREET NAME                         458746       21.446270
# VEHICLE TYPE CODE 2                    417714       19.528033
# CONTRIBUTING FACTOR VEHICLE 2          336447       15.728820
# LOCATION                               239440       11.193765
# LONGITUDE                              239440       11.193765
# LATITUDE                               239440       11.193765
# VEHICLE TYPE CODE 1                     14731        0.688671
# CONTRIBUTING FACTOR VEHICLE 1            7247        0.338796
# NUMBER OF PERSONS KILLED                   31        0.001449
# NUMBER OF PERSONS INJURED                  18        0.000841
# COLLISION_ID                                0        0.000000
# CRASH DATE                                  0        0.000000
# NUMBER OF MOTORIST KILLED                   0        0.000000
# NUMBER OF MOTORIST INJURED                  0        0.000000
# NUMBER OF CYCLIST KILLED                    0        0.000000
# CRASH TIME                                  0        0.000000
# NUMBER OF PEDESTRIANS KILLED                0        0.000000
# NUMBER OF PEDESTRIANS INJURED               0        0.000000
# NUMBER OF CYCLIST INJURED                   0        0.000000

# %% [markdown]
# Here's an overview of the missing values in the dataset:
#
# Columns like VEHICLE TYPE CODE 5, CONTRIBUTING FACTOR VEHICLE 5, VEHICLE TYPE CODE 4, and so on have a high percentage of missing values. This is expected since not all crashes involve multiple vehicles or factors.
#
# OFF STREET NAME and CROSS STREET NAME have significant missing values. This could be due to crashes occurring in locations where these details aren't applicable or weren't recorded.
#
# ZIP CODE, BOROUGH, and ON STREET NAME also have missing values. This might be due to incomplete data entry or crashes occurring in areas where these specifics aren't easily determinable.
#
# LOCATION, LATITUDE, and LONGITUDE have the same count of missing values, indicating that when one is missing, the others are likely missing as well.

# %% [markdown]
# **Step 3:** Create a bar chart to display the top 10 contributing factors (e.g. backing up unsafely, unsafe lane changing, etc.) to crashes within the dataset.

# %%
#TODO: Plot a Bar Chart

top_factors = data['CONTRIBUTING FACTOR VEHICLE 1'].value_counts().head(10)


plt.figure(figsize=(12, 7))
# TODO: Plotting the top contributing factors

# TODO: Plotting the top contributing factors, fill in x as the index field of the variable 'top_factors'
sns.barplot(x=data['CONTRIBUTING FACTOR VEHICLE 1'].head(10), y=top_factors.values, palette="magma")
plt.title('Top 10 Contributing Factors to crashes', fontsize=16)
plt.xlabel('Contributing Factors to crashes', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-11-7f3fb802bbeb>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data['CONTRIBUTING FACTOR VEHICLE 1'].head(10), y=top_factors.values, palette="magma")

# %% [markdown]
# **TO DO:** Besides for "Unspecified," what are the top 3 contributing factors that cause the most crashes?
#
# > *  Aggressive Driving/Road Rage
# > *  Pavement Slippery
# > *  Following Too Closely

# %% [markdown]
# **TO DO:** What recommendations would you make to new and current drivers after assessing the above data?
#
# > *   My main recommendation would be to be mindful about how and where you are driving. Being more alert about the surroundings and following proper traffic rules may save you from tragic incidents.

# %% [markdown]
# **Step 4:** Now, let's create another bar chart to determine which vehicle types were involved in the most crashes.

# %%
# Determine the top vehicle types involved in crashes
top_vehicle_types = data['VEHICLE TYPE CODE 1'].value_counts().head(15)

# Plotting the top vehicle types
plt.figure(figsize=(12, 7))
sns.barplot(x=data['VEHICLE TYPE CODE 1'].head(15), y=top_vehicle_types.values, palette="cividis")
plt.title('Top 10 Vehicle Types Involved in crashes', fontsize=16)
plt.xlabel('Vehicle Type', fontsize=14)
plt.ylabel('Number of crashes', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-17-9f6273e9508f>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data['VEHICLE TYPE CODE 1'].head(15), y=top_vehicle_types.values, palette="cividis")

# %% [markdown]
# **TO DO:** What are the top 3 vehicles that were most involved in crashes?
#
#
# > *   Sedan
# > *   Dump
# > *   Station Wagon/Sport Utility Vehicle

# %% [markdown]
# **TO DO:** Why do you think that "Sedan[s]," "Station Wagon[s]," and "Passenger Vehicle[s]" are involved in a larger number of crashes, injuries, and deaths when compared to the rest of the vehicles? (Think outside the box!)
#
#
# > *  Since the drivers are driving their own vehicles they have complete control over the speed and can go faster if they are in a hurry. Whereas for busses and taxies, the driver is not concerned with the haste of the passenger and will follow fixed speed limits.

# %% [markdown]
# **TO DO:** Review the x-axis of the bar chart you created above. </br>
# 1) What do you notice? </br>
# 2) What would you recommend we do to improve the bar chart, based on the x-axis (horizontal axis) and why? </br>
# 3) What recommendation would you make to those who are collecting and/or inputting data into this dataset?
#
#
# > *  1) There is a long Error Bar in the chart for Sedan's bar. The error line is almost as long as the actual bar which indicate a possibility of 50% error in the values. Error bars are a graphical representation of the variability of data and are used on graphs to indicate the error, or uncertainty in a reported measurement. [Ref](https://stackoverflow.com/questions/35193996/what-is-the-overlay-line-on-each-bar-in-a-bar-chart)
# > *  2) We need to reduce the error margine in the data to reduce the error bar length and have more accurate data for analysis.
# > *  3) Recommendations for data collectors:
#   - Use precise and unambiguous questions in surveys or data collection instruments to minimize interpretation errors.
#   - Use drop-down menus for data entry where appropriate to limit potential errors by providing pre-defined options.
#   - Utilize specialized data management software with features like data validation rules, data cleaning tools, and audit trails.
#   - Provide comprehensive training to data collectors and data entry personnel on data collection protocols and data entry guidelines.

# %% [markdown]
# **Step 5:**  A DataFrame is a two-dimensional and potentially heterogeneous tabular data structure with labeled axes (rows and columns). DataFrames allow for storing, manipulating, and retrieving data in a structured form, serving as the primary data structure for a multitude of data processing tasks. It is used with Python libraries like pandas.
#
# Let's graph the *types* of crashes within this dataset and their frequencies. Begin by aggregating your data, convert to [DataFrame](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html) for simple plotting, and plot.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Aggregating data - Complete for Cyclist and Motorist
types_of_crashes = {
    'Pedestrian Injuries': data['NUMBER OF PEDESTRIANS INJURED'].sum(),
    'Cyclist Injuries': data['NUMBER OF CYCLIST INJURED'].sum(),
    'Motorist Injuries': data['NUMBER OF MOTORIST INJURED'].sum(),
    'Pedestrian Deaths': data['NUMBER OF PEDESTRIANS KILLED'].sum(),
    'Cyclist Deaths': data['NUMBER OF CYCLIST KILLED'].sum(),
    'Motorist Deaths': data['NUMBER OF MOTORIST INJURED'].sum()
}

# Converting to DataFrame for easier plotting - we want the items in the dictionary, use the items function
crash_types_df = pd.DataFrame(list(types_of_crashes.items()), columns=['crash Type', 'Count'])

# Plot
plt.figure(figsize=(12, 7))
sns.barplot(x='Count', y='crash Type', data=crash_types_df, palette="mako")
plt.title('Types of crashes and Their Frequencies')
plt.xlabel('Count')
plt.ylabel('Type of crash')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-18-cf2bbf21cf7f>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Count', y='crash Type', data=crash_types_df, palette="mako")

# %% [markdown]
# **TO DO:** Analyze the chart above. What is a recommendation you might make to the Department of Transportation based on this data?
#
#
# > *  Probably asigning a different lane to motorists would make it safer to drive motor bikes on streets. More safety protocols could be introduced to keep motorists safe and out of harms way.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'> **Milestone #3 - Time Series Analysis**</font>
# GOAL: The main goal of this milestone is to dive deeper into Time Series Analysis in order to better understand our data's trends over time.

# %% [markdown]
# **Step 1:**
#
# Before we jump into Time Series Analysis (TSA), it's important to understand the basics, including Trends, Seasonality, and Residual Components.
#
# Review one or more of the following resources and tell us what you learned about TSA!
#
# *  [Learn about Time Series patterns here](https://otexts.com/fpp2/tspatterns.html)
# * [Learn about Time Plots here](https://otexts.com/fpp2/time-plots.html)
# *[Learn how to decompose Time Series Data into Trend and Seasonality](https://machinelearningmastery.com/decompose-time-series-data-trend-seasonality/)

# %% [markdown]
# **TO DO:** Write 3-5 sentences about TSA.
# > *  Time Series Analysis can be done primarily using graphs plotting observations against the time when those observations were takesn.
# * These graphs help us identify patterns in the observed data over a period of time which can then be used to predict future behaviour.
# * Patterns can roughly be classified into three types: *Trend*, *Seasonal* pattern and *Cyclic* pattern.
# * A ***Trend*** can be explained a the direction in which the obeservations appear to be increasing/decreasing over a long period of time/in general/since start. For example, the popularity of a particular food chain could be going up and down each year but, if we consider its popularity from the day of its opening till today, we might notice that it has been increasingly growing which appears to be the *trend* in the popularity of this food chain.
# * A ***Seasonal pattern*** is observed over a short period of time like a week, month or a year and is mainly related to the time of week/month/year. For example, there are more flight bookings during the time of Thanksgiving or Christmas as compared to any other normal day in the year. This is called a seasonal pattern because every year, during this time, this same behaviour has been and will be observed.
# * Finally ***Cyclic pattern*** is seen when a particular behaviur is seen to repeat after some amount of time, like a few years or decades. For example, Fashion trens seem to have a cycle where a new Fashion trend is introduced, becomes very popular and the slowly loses popularity until a new Fashion is introduced.

# %% [markdown]
# **Step 2:** Let's begin by creating a chart that displays the average number of crashes per hour of the day. This will help us understand whether additional factors are contributing to crashes - i.e. rush hour, school dismissal time, night fall, etc.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the dataset
file_path = "/content/drive/MyDrive/Colab Notebooks/Motor_Vehicle_Collisions_-_Crashes_20241204.csv"
data = pd.read_csv(file_path)

# Convert 'CRASH DATE' and 'CRASH TIME' to datetime
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])
data['CRASH TIME'] = pd.to_datetime(data['CRASH TIME'], format='%H:%M')

# Time of Day Analysis
data['Hour of Day'] = data['CRASH TIME'].dt.hour

# Group by 'Hour of Day' and calculate the average number of crashes per hour
average_crashes_per_hour = data.groupby('Hour of Day').size() / data['Hour of Day'].nunique()

# Plot the average number of crashes
plt.figure(figsize=(12, 6))
sns.barplot(x=data['Hour of Day'], y=average_crashes_per_hour)
plt.title('Average Number of crashes per Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Average Number of crashes')
plt.xticks(range(0, 24))
plt.show()
# Out:
# <ipython-input-5-d05b2883d1c3>:7: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)

# %% [markdown]
# **TO DO:** Which time of the day sees the most crashes? Why do you think so?
#
# > *  Most of the crashes appear to have happened in the night.
# * This could be because of low visibility and/or sleepiness.

# %% [markdown]
# **Step 3:**
# Plot a graph to determine how COVID-19 impacted the number of crashes per month, if at all.

# %%
# Convert 'CRASH DATE' to datetime format
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])

# Group by month and year to get the number of crashes per month
monthly_crashes = data.groupby(data['CRASH DATE'].dt.to_period("M")).size()

# Plotting the trend over time
plt.figure(figsize=(15, 7))
monthly_crashes.plot()
plt.title('Number of Crashes per Month', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# **TO DO:** What does your graph tell you about the impact of COVID-19 on the number of crashes per month? Why do you think this occurred?
#
# > * COVID-19 significantly reduced the number of crashes, almost reaching to less than 2500 crashes per month in the first quarter of 2020.
# * This is because of the complete lockdown enforced in the country during that time.
# * The crashes didn't go up right away after that as people were still skeptical to go out for a long time.

# %% [markdown]
# **Step 4**: Apply time series decomposition to review trends, seasonality, and residuals. New to time series analysis? Review the [Time Series Flashcard video series](https://youtube.com/playlist?list=PLNs9ZO9jGtUAqd0CNKySksPJJaOqYPMvk&feature=shared) here to learn about trends, components, and further analysis!

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose

# Count the number of crashes per day, group by CRASH DATE
daily_crashes = data.groupby(data['CRASH DATE']).size()

# Set plot style
sns.set(style="darkgrid")

# Plot the daily crashes time series
plt.figure(figsize=(15, 6))
plt.plot(daily_crashes, label='Daily crashes')
plt.title('Daily Motor Vehicle Collisions in NYC')
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.legend()
plt.show()

# Decompose the time series
decomposition = seasonal_decompose(daily_crashes, model='additive', period=365)

# Plot the decomposed components
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(15, 12))
decomposition.trend.plot(ax=ax1)
ax1.set_title('Trend')
decomposition.seasonal.plot(ax=ax2)
ax2.set_title('Seasonal Patterns')
decomposition.resid.plot(ax=ax3)
ax3.set_title('Residuals')
plt.tight_layout()
plt.show()

# %% [markdown]
# The visualizations above provide valuable insights into the time series of daily motor vehicle collisions in New York City:
#
# 1. Time Series Plot: This shows the number of daily crashes over time. You might observe long-term trends, seasonal patterns, or significant outliers.
#
# 2. Decomposed Components:
#
#     2.1 Trend: This graph shows the long-term trend in the data, which can indicate whether crashes are increasing, decreasing, or stable over time.
#
#     2.2 Seasonality: This reveals any regular patterns that repeat over a specific period, such as yearly. It helps identify times of the year with higher or lower crash frequencies.
#
#     2.3 Residuals: These are the irregular components that cannot be attributed to the trend or seasonality. They might include random or unpredictable fluctuations.

# %% [markdown]
# **TO DO:** Based on your *trend graph*, are we seeing an increase or a decrease in crashes between 2014 and 2022?
#
# > *  There is an increasing trend till the year 2019. Then the rate suddenly dropped in 2020 and then increased slightly till 2022
#
#
# **TO DO:** Based on your *residual graph*, in what year(s) was there a significant unpredicted fluctuation? Why do you think so?
#
# > *  2014 and 2020. The fluctuation in 2020 was because of COVID-19

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'>**Milestone #4 - Geospatial Analysis**</font>
# GOAL: The main goal of this milestone is to explore geospatial aspects of the dataset and get comfortable with regional analysis and geospatial visualizations.

# %% [markdown]
# **Step 1:** Before beginning this Milestone, we highly recommend that you review the [NSDC Geospatial Analysis Flashcard Video series](https://www.youtube.com/playlist?list=PLNs9ZO9jGtUAX_2g1-OJp8VkmVum6DqqP) if you are new to Geospatial Analysis!
#
# Let's build a bar chart to compare and analyze the number of crashes across the five boroughs: Brooklyn (also known as Kings County), Queens, Manhattan, Bronx, and Staten Island.

# %%
#TODO: Plot a bar chart to compare the number of crashes that occurred in each of the five boroughs.
# Set style
sns.set_style("whitegrid")

# Plotting the distribution of crashes by borough
plt.figure(figsize=(12, 7))
# Find the count of unique values of BOROUGHS. Hint: Use value_count function.
borough_count = data['BOROUGH'].value_counts()
sns.barplot(x=borough_count.index, y=borough_count.values, palette="viridis")
plt.title('Distribution of Crashes by Borough', fontsize=16)
plt.xlabel('Borough', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-6-4f14068022f4>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=borough_count.index, y=borough_count.values, palette="viridis")

# %% [markdown]
# **TO DO:** Which borough has the highest number of crashes? Which borough has the lowest?
#
# > * Highest: Brooklyn
# > * Lowest: Staten Island
#
#
# **TO DO:** Are there any reasons that you think a certain borough has a higher or lower number of crashes? What are some factors that may be causing this?
#
# > *  There are a couple of factors that could be causing this:
# 1. Brooklyn is more populated compared to Staten Island which also corresponds to the number of vehicles in the area. More the number of vehicles, more is the probability of accidents happening in the region.
# 2. Next, Brooklyn is a bustling city with more activities happening compared to Staten Island which is a suburban area where people are more laid-back. Brooklyn experiences more rush which could be a cause of the higher number of incidents there.

# %% [markdown]
# **Step 2:** Heatmaps are graphical representations that use color coding to represent different values and variables. Let's leverage a heatmap to determine the most dangerous intersections in the dataset. (**Note: the below cell may take a few minutes to run**)

# %%
#TODO: Create a heatmap leveraging the latitude and longitude variables to determine where the most crashes are occurring
from folium.plugins import HeatMap

# Drop rows with missing latitude and longitude values
data_geo = data.dropna(subset=['LATITUDE', 'LONGITUDE'])

# Create a base map
m = folium.Map(location=[40.730610, -73.935242], zoom_start=10)  # Centered around NYC

# Create a heatmap
heat_data = [[row['LATITUDE'], row['LONGITUDE']] for index, row in data_geo.iterrows()]
HeatMap(heat_data, radius=8, max_zoom=13).add_to(m)

m.save("Heatmap.html")

# %% [markdown]
# **TO DO:** On the left side of your screen, you will see an icon that represents a folder or a file. Click on that icon to find the file titled "Heatmap.html". Click on the three dots next to your file and download your heatmap! Open the file once downloaded to see your creation.
#
# When looking at your heatmap, where do you see a concentration of crashes?
#
#
# > *  The concentration of crashes is higher in Manhattan in the Midtown Area and Lower Manhattan

# %% [markdown]
# **Step 3:** Next, we will begin "Severity Mapping." We'll plot crashes on the map and code them based on severity, distinguishing between crashes that resulted in injuries and those that led to fatalities. This will give us a visual representation of where severe crashes tend to occur. </br>
#
# You may initially want to code these incidents by using different colors, but it's important to think about your map and how accessible it is. Will a color-coded map be easy to read for everyone? Let's make a map that's inclusive for people with color blindness by also creating differently-shaped markers (squares, circles, and triangles) for crashes, injuries, and fatalities.

# %%
#TODO: Continue building your heatmap
# Sample a subset of the data for visualization
sample_data_severity = data_geo.sample(n=1000, random_state=42)

# Create a base map
m_severity = folium.Map(location=[40.730610, -73.935242], zoom_start=10)

# Add crashes to the map with color coding and shape coding based on severity
for index, row in sample_data_severity.iterrows():
    if row['NUMBER OF PERSONS KILLED'] > 0:
        color = "red"  # Fatalities

        folium.features.RegularPolygonMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          number_of_sides=3,
          radius=5,
          gradient = False,
          color=color,
          fill=True,
          fill_color=color
        ).add_to(m_severity)


    elif row['NUMBER OF PERSONS INJURED'] > 0:
        color = "blue"  # Injuries
        folium.CircleMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          radius=5,
          color=color,
          fill=True,
          fill_color=color
       ).add_to(m_severity)
    else:
        color = "green"  # No injuries or fatalities
        folium.features.RegularPolygonMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          number_of_sides=4,
          radius=5,
          gradient = False,
          color=color,
          fill=True,
          fill_color=color
        ).add_to(m_severity)


m_severity.save("severity.html")

# %% [markdown]
# **TO DO:** On the left side of your screen, you will see an icon that represents a folder or a file. Follow the same steps as above to download the "Severity.html" file.
#
# **TO DO:** Which intersection(s) seem to be the most dangerous?
#
# > *  The Atlantic Ave and 85th Street intersection in Brooklyn is the most dangerous intersection as it has had fatal incidents before

# %% [markdown]
# ---
# ---

# %% [markdown]
# ##<font color='crimson'>  **Milestone #5 - Self-Guided Research Question**</font>
# GOAL: In this Milestone, you will be prompted to take what you’ve learned throughout this project, build your own research question, and create a visualization(s) or model(s) to support your research goals.

# %% [markdown]
# ***Note:*** *This module can be run independently without the need of running any other pre-processing steps from above modules first*

# %% [markdown]
# ### Objective
# To study pedestrian safety using transportation data and identify actionable insights for various stakeholders, including pedestrians, drivers, transportation professionals, and the general public.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1. Data Preparation

# %%
# TODO: Read the data using pandas read_csv function
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Motor_Vehicle_Collisions_-_Crashes_20241204.csv")
# Out:
# <ipython-input-3-894fbebb6d67>:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Motor_Vehicle_Collisions_-_Crashes_20241204.csv")

# %%
# TODO: Print the first 5 rows of the data using head function of pandas
data.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                      NaN  ...                    Unspecified
# 1                      NaN  ...                            NaN
# 2                      NaN  ...                    Unspecified
# 3  1211      LORING AVENUE  ...                            NaN
# 4                      NaN  ...                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  VEHICLE TYPE CODE 1  \
# 0                            NaN       4455765                Sedan
# 1                            NaN       4513547                Sedan
# 2                            NaN       4541903                Sedan
# 3                            NaN       4456314                Sedan
# 4                            NaN       4486609                  NaN
#
#    VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4  \
# 0                Sedan                  NaN                 NaN
# 1                  NaN                  NaN                 NaN
# 2        Pick-up Truck                  NaN                 NaN
# 3                  NaN                  NaN                 NaN
# 4                  NaN                  NaN                 NaN
#
#   VEHICLE TYPE CODE 5
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# ## 2. Visualizations and Analyses

# %% [markdown]
# ### A. Borough-Wise Pedestrian Involvement

# %%
#TO DO: Begin creating here!
# Plot the number of pedestrians involved in crash in each of the boroughs
# X-axis: name of borough, Y-axis: number of pedestrians involved in crash

# Drop rows with missing values in relevant columns
data = data.dropna(subset=['BOROUGH', 'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED'])

# Calculate the total number of pedestrians involved (injured + killed) for each borough
data['TOTAL_PEDESTRIANS_INVOLVED'] = data['NUMBER OF PEDESTRIANS INJURED'] + data['NUMBER OF PEDESTRIANS KILLED']

# Aggregate the total number of pedestrians involved by borough
borough_totals = data.groupby('BOROUGH')['TOTAL_PEDESTRIANS_INVOLVED'].sum().reset_index()

# Sort boroughs by total number of pedestrians involved for better visualization
borough_totals = borough_totals.sort_values(by='TOTAL_PEDESTRIANS_INVOLVED', ascending=False)

# Plot the data
plt.figure(figsize=(12, 7))
sns.barplot(
    data=borough_totals,
    x='BOROUGH',
    y='TOTAL_PEDESTRIANS_INVOLVED',
    palette='viridis'
)

# Add labels and title
plt.title('Total Pedestrians Involved in Crashes by Borough', fontsize=16)
plt.xlabel('Borough', fontsize=14)
plt.ylabel('Number of Pedestrians Involved', fontsize=14)

# Rotate x-axis labels
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-5-7e0e1c12b71e>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['TOTAL_PEDESTRIANS_INVOLVED'] = data['NUMBER OF PEDESTRIANS INJURED'] + data['NUMBER OF PEDESTRIANS KILLED']
# <ipython-input-5-7e0e1c12b71e>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
data['ON STREET NAME'].count()
data['CROSS STREET NAME'].count()
data['TOTAL_PEDESTRIANS_INVOLVED'].count()
data.count()
# Out:
# CRASH DATE                       1475000
# CRASH TIME                       1475000
# BOROUGH                          1475000
# ZIP CODE                         1474738
# LATITUDE                         1437556
# LONGITUDE                        1437556
# LOCATION                         1437556
# ON STREET NAME                   1143850
# CROSS STREET NAME                1143270
# OFF STREET NAME                   330589
# NUMBER OF PERSONS INJURED        1474989
# NUMBER OF PERSONS KILLED         1474977
# NUMBER OF PEDESTRIANS INJURED    1475000
# NUMBER OF PEDESTRIANS KILLED     1475000
# NUMBER OF CYCLIST INJURED        1475000
# NUMBER OF CYCLIST KILLED         1475000
# NUMBER OF MOTORIST INJURED       1475000
# NUMBER OF MOTORIST KILLED        1475000
# CONTRIBUTING FACTOR VEHICLE 1    1469372
# CONTRIBUTING FACTOR VEHICLE 2    1229638
# CONTRIBUTING FACTOR VEHICLE 3      92341
# CONTRIBUTING FACTOR VEHICLE 4      21899
# CONTRIBUTING FACTOR VEHICLE 5       6282
# COLLISION_ID                     1475000
# VEHICLE TYPE CODE 1              1463813
# VEHICLE TYPE CODE 2              1172729
# VEHICLE TYPE CODE 3                89006
# VEHICLE TYPE CODE 4                21223
# VEHICLE TYPE CODE 5                 6120
# TOTAL_PEDESTRIANS_INVOLVED       1475000
# dtype: int64

# %%
borough_totals
# Out:
#          BOROUGH  TOTAL_PEDESTRIANS_INVOLVED
# 1       BROOKLYN                       33926
# 3         QUEENS                       23857
# 2      MANHATTAN                       22701
# 0          BRONX                       16553
# 4  STATEN ISLAND                        2762

# %% [markdown]
# #### **Analysis**
#
# Brooklyn has the highest number of pedestrian crashes (\~35,000), while Staten Island has the lowest (\~5,000). This disparity is largely influenced by population density, number of households, and intersection density. While Brooklyn's population is four times that of Staten Island, the number of households in Brooklyn is ten times greater. This explains Brooklyn's higher housing density, which contributes to greater pedestrian activity and higher crash occurrences. Brooklyn also has the highest number of intersections (4,848) compared to Staten Island's 633, further increasing the likelihood of crashes. Additionally, 78.76% of all crashes occur at intersections, underscoring the critical need for targeted safety measures at these locations.

# %% [markdown]
# #### **Insights**
#
# Brooklyn has the highest number of pedestrian crashes, followed by Queens and Manhattan, while Staten Island has the least.
# Contributing Factors:
# - Higher population density and a significantly larger number of intersections in Brooklyn likely contribute to the higher number of crashes.
# - Staten Island's smaller population, fewer intersections, and less urbanized environment make it comparatively safer.

# %% [markdown]
# ### B. Ratio of Total Crashes to Pedestrian Involvement
# A stacked bar graph showing total crashes vs. pedestrian involvement per borough.

# %%
# Percentage of pedestrians in crashes

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Drop rows with missing values in relevant columns
data = data.dropna(subset=['BOROUGH', 'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED'])

# Calculate the total number of pedestrians involved (injured + killed) for each borough
data['TOTAL_PEDESTRIANS_INVOLVED'] = data['NUMBER OF PEDESTRIANS INJURED'] + data['NUMBER OF PEDESTRIANS KILLED']

# Calculate the total number of crashes in each borough
borough_crash_counts = data['BOROUGH'].value_counts().reset_index()
borough_crash_counts.columns = ['BOROUGH', 'TOTAL_CRASHES']

# Aggregate the total number of pedestrians involved by borough
borough_pedestrian_totals = data.groupby('BOROUGH')['TOTAL_PEDESTRIANS_INVOLVED'].sum().reset_index()

# Merge the pedestrian totals and crash counts
borough_data = pd.merge(borough_crash_counts, borough_pedestrian_totals, on='BOROUGH')

# Calculate the percentage of pedestrians involved per crash in each borough
borough_data['PERCENT_PEDESTRIANS_INVOLVED'] = (borough_data['TOTAL_PEDESTRIANS_INVOLVED'] / borough_data['TOTAL_CRASHES']) * 100

# Sort data for visualization
borough_data = borough_data.sort_values(by='TOTAL_CRASHES', ascending=False)

# Plot the divided bar graph
plt.figure(figsize=(12, 7))
sns.barplot(
    data=borough_data,
    x='BOROUGH',
    y='TOTAL_CRASHES',
    color='lightgrey',
    label='Total Crashes'
)

sns.barplot(
    data=borough_data,
    x='BOROUGH',
    y='TOTAL_PEDESTRIANS_INVOLVED',
    color='dodgerblue',
    label='Pedestrians Involved'
)

# Add labels and title
plt.title('Crashes and Pedestrian Involvement by Borough', fontsize=16)
plt.xlabel('Borough', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Add legend
plt.legend(title='Metrics', fontsize=12, title_fontsize=12)

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# #### **Analysis**
#
# Analysis of graph ***Crashes and Pedestrian Involvement by Borough***
#
# This bar graph compares the total number of crashes and the subset of crashes involving pedestrians across the five boroughs of New York City: Brooklyn, Queens, Manhattan, the Bronx, and Staten Island.
#
# **Key Observations:**
#
# **1. Total Crashes:**
#
# - Brooklyn has the highest total number of crashes, followed closely by Queens and Manhattan.
# - Staten Island has the lowest total crashes by a significant margin, with fewer than one-fourth of the crashes compared to Manhattan.
# - The Bronx ranks fourth in total crashes, ahead of Staten Island but well below Manhattan.
#
# **2. Pedestrian Involvement:**
#
# - Brooklyn also leads in pedestrian-involved crashes, with the highest count among the boroughs.
# - The proportion of pedestrian-involved crashes relative to the total crashes appears consistent across all boroughs.
# - Staten Island has the lowest number of pedestrian-involved crashes, reflecting its lower population density and fewer intersections.
#
# **Proportional Analysis:**
#
# **1. Brooklyn:**
#
# - The majority of crashes in Brooklyn are not pedestrian-related, as indicated by the smaller blue bar compared to the grey bar.
# - Despite this, Brooklyn's pedestrian involvement is still the highest among all boroughs due to its dense population, high household density, and the highest number of intersections.
#
# **2. Queens:**
#
# - Queens follows a similar trend to Brooklyn, with a high total crash count and relatively lower pedestrian involvement compared to the total.
#
# **3. Manhattan:**
#
# - Manhattan shows a slightly higher proportion of pedestrian-involved crashes relative to its total crashes, possibly due to its compact geography, high pedestrian foot traffic, and busy urban streets.
#
# **4. The Bronx:**
#
# - The Bronx has fewer total crashes compared to Brooklyn, Queens, and Manhattan. The pedestrian involvement count is also correspondingly lower.
#
# **5. Staten Island:**
#
# - Staten Island's total crashes and pedestrian involvement are minimal compared to the other boroughs, likely due to its smaller population, lower intersection density, and suburban layout.

# %% [markdown]
# #### **Insights**
#
# Although Brooklyn has the highest number of pedestrian crashes, the proportion of pedestrian involvement relative to total crashes is lower compared to other boroughs like Manhattan. This suggests that while Brooklyn has more crashes overall, pedestrians might face relatively less risk due to factors like traffic calming measures or pedestrian-friendly infrastructure.
#
#
# **1. Population and Intersection Density:**
#
# - Brooklyn and Queens, being the most populous boroughs with the highest intersection density, experience the highest total crashes and pedestrian involvement. This aligns with the expected correlation between population, infrastructure, and crash incidents.
#
# **2. Pedestrian Risks in Manhattan:**
#
# - Manhattan's proportionally higher pedestrian involvement in crashes suggests that its urban density and high pedestrian activity create unique challenges for pedestrian safety.
#
# **3. Safer Boroughs:**
#
# - Staten Island stands out as the safest borough for both total crashes and pedestrian involvement, attributed to its lower population density and suburban nature.
#
# **4. Brooklyn vs. Staten Island:**
#
# - Brooklyn's crash count is disproportionately higher than Staten Island’s, with a difference influenced by population density, number of households, and infrastructure (e.g., intersections).

# %% [markdown]
# ### C. Top Contributing Factors to Pedestrian Crashes
# Bar graph for the top 10 contributing factors.

# %%
# Find the number of pedestrians for each type of contributing factors to find the most affecting factor in accidents involving pedestrians
# X-axis: contributing factors, Y-axis: number of pedestrians involved in crash

# Filter out rows where the contributing factor is "Unspecified"
filtered_data_1 = data[data['CONTRIBUTING FACTOR VEHICLE 1'] != 'Unspecified']
filtered_data_2 = data[data['CONTRIBUTING FACTOR VEHICLE 2'] != 'Unspecified']
filtered_data_3 = data[data['CONTRIBUTING FACTOR VEHICLE 3'] != 'Unspecified']
filtered_data_4 = data[data['CONTRIBUTING FACTOR VEHICLE 4'] != 'Unspecified']
filtered_data_5 = data[data['CONTRIBUTING FACTOR VEHICLE 5'] != 'Unspecified']

# Reset index for all Contributing Factor columns
factor_totals_1 = filtered_data_1.groupby('CONTRIBUTING FACTOR VEHICLE 1')['TOTAL_PEDESTRIANS_INVOLVED'].sum().reset_index()
factor_totals_2 = filtered_data_2.groupby('CONTRIBUTING FACTOR VEHICLE 2')['TOTAL_PEDESTRIANS_INVOLVED'].sum().reset_index()
factor_totals_3 = filtered_data_3.groupby('CONTRIBUTING FACTOR VEHICLE 3')['TOTAL_PEDESTRIANS_INVOLVED'].sum().reset_index()
factor_totals_4 = filtered_data_4.groupby('CONTRIBUTING FACTOR VEHICLE 4')['TOTAL_PEDESTRIANS_INVOLVED'].sum().reset_index()
factor_totals_5 = filtered_data_5.groupby('CONTRIBUTING FACTOR VEHICLE 5')['TOTAL_PEDESTRIANS_INVOLVED'].sum().reset_index()

# Set the Contributing Factor columns as index in each dataframe
factor_totals_1.set_index('CONTRIBUTING FACTOR VEHICLE 1', inplace=True)
factor_totals_2.set_index('CONTRIBUTING FACTOR VEHICLE 2', inplace=True)
factor_totals_3.set_index('CONTRIBUTING FACTOR VEHICLE 3', inplace=True)
factor_totals_4.set_index('CONTRIBUTING FACTOR VEHICLE 4', inplace=True)
factor_totals_5.set_index('CONTRIBUTING FACTOR VEHICLE 5', inplace=True)


# Aggregate the total number of pedestrians involved for each contributing factor
factor_totals_1['TOTAL_PEDESTRIANS_INVOLVED_COMBINED'] = factor_totals_1['TOTAL_PEDESTRIANS_INVOLVED'].fillna(0) + factor_totals_2['TOTAL_PEDESTRIANS_INVOLVED'].fillna(0) + factor_totals_3['TOTAL_PEDESTRIANS_INVOLVED'].fillna(0) + factor_totals_4['TOTAL_PEDESTRIANS_INVOLVED'].fillna(0) + factor_totals_5['TOTAL_PEDESTRIANS_INVOLVED'].fillna(0)
factor_totals_1.drop('TOTAL_PEDESTRIANS_INVOLVED', axis=1, inplace=True)
factor_totals_1 = factor_totals_1.dropna().sort_values(by='TOTAL_PEDESTRIANS_INVOLVED_COMBINED', ascending=False)
# factor_totals_1
top_10_contributing_factors_all = factor_totals_1.head(10)

# Plot the data
plt.figure(figsize=(12, 7))
sns.barplot(
    data=top_10_contributing_factors_all,
    x='CONTRIBUTING FACTOR VEHICLE 1',
    y='TOTAL_PEDESTRIANS_INVOLVED_COMBINED',
    palette='viridis'
)

# Add labels and title
plt.title('Top 10 Contributing Factors in Pedestrian Crashes', fontsize=16)
plt.xlabel('Contributing Factors for all Vehicles', fontsize=14)
plt.ylabel('Number of Pedestrians Involved', fontsize=14)

# Rotate and align x-axis labels
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-17-1276f3fd7e05>:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# #### **Analysis**
#
# Analysis of graph ***Top 10 Contributing Factors in Pedestrian Crashes***
#
# - Driver Inattention/Distraction is the leading contributing factor, accounting for nearly 20,000 pedestrian-involved crashes. This highlights the significant role of distracted driving in pedestrian accidents.
# - Failure to Yield Right-of-Way is the second most common factor, with nearly 18,000 cases. This underscores issues related to drivers failing to follow traffic rules, particularly at intersections and crosswalks.

# %% [markdown]
# #### **Insights**
#
# **1. Driver-Related Factors Dominate:**
#
# - The graph clearly shows that the majority of pedestrian crashes are caused by driver behavior, particularly inattention, distraction, and failure to yield. These factors are preventable through better driver education, enforcement of traffic rules, and increased awareness.
#
# **2. Intersection Safety:**
#
# - The high numbers for "Failure to Yield Right-of-Way" and "Traffic Control Disregarded" suggest that intersections are high-risk zones for pedestrians. Proper signaling, pedestrian crosswalk enforcement, and redesign of intersections could reduce such incidents.
#
# **3. Environmental and Situational Factors:**
#
# - Factors like slippery pavement and passing too closely are relatively minor but could still pose serious risks, especially in adverse weather conditions.
#
# **4. Driver Training and Awareness:**
#
# - The presence of "Driver Inexperience" and "Aggressive Driving/Road Rage" indicates a need for improved driver training and programs to address road rage and stress management among drivers.

# %% [markdown]
# ### D. Intersection vs. Non-Intersection Crashes
# Pie chart showing the proportion of crashes at intersections vs. non-intersections.

# %%
### Intersection vs. Non-Intersection Crashes ###
intersection_crashes = data.dropna(subset=['ON STREET NAME', 'CROSS STREET NAME'])
non_intersection_crashes = data[data['ON STREET NAME'].isna() | data['CROSS STREET NAME'].isna()]

labels = ['Intersection Crashes', 'Non-Intersection Crashes']
values = [len(intersection_crashes), len(non_intersection_crashes)]

plt.figure(figsize=(8, 6))
plt.pie(values, labels=labels, autopct='%1.1f%%', colors=['red', 'green'], startangle=90)
plt.title('Proportion of Intersection vs. Non-Intersection Crashes')
plt.show()

# %% [markdown]
# #### **Analysis**
#
# Majority of incidents take place on intersections and from the previous analysis it was observed that driver inattention is the major reason for incidents involving pedestrians.
#
# These two observations can help us determine that there needs to be some safety protocal implemented on intersections that will ensure safer crossing for pedestrians.
#
# **1. Dominance of Intersection Crashes:**
#
# - Intersection crashes account for 77.5% of all crashes, significantly overshadowing the 22.5% of non-intersection crashes.
# - This indicates that intersections are high-risk zones for vehicular and pedestrian collisions.
#
# **2. Intersection Risk Factors:**
#
# - The high proportion of crashes at intersections could be attributed to:
#   - Confusion or conflicts between pedestrians and vehicles.
#   - Driver behaviors such as failure to yield, inattention, or speeding.
#   - Complex traffic patterns and inadequate signaling.
#
# **3. Non-Intersection Crashes:**
#
# - While accounting for a smaller percentage, non-intersection crashes often occur due to:
#   - High-speed zones or highways where intersections are absent.
#   - Pedestrians jaywalking or crossing roads at undesignated areas.
#
# **4. Implications for Pedestrians:**
#
# - The high percentage of intersection crashes highlights the vulnerability of pedestrians crossing roads at designated crossings.

# %% [markdown]
# #### **Insights**
#
# A large majority of crashes (77.5%) occur at intersections, further emphasizing the need for enhanced safety measures at these locations.

# %% [markdown]
# ### E. Time Series Analysis of Pedestrian Crashes by Hour of Day
# Line graph of pedestrian involvement in crashes by hour.

# %%
# Plot number of crashes against hour of the day
### Time of Day Analysis ###
data['HOUR'] = pd.to_datetime(data['CRASH TIME'], format='%H:%M').dt.hour
hourly_totals = data.groupby('HOUR')['TOTAL_PEDESTRIANS_INVOLVED'].sum().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(x='HOUR', y='TOTAL_PEDESTRIANS_INVOLVED', data=hourly_totals, marker='o', color='blue')
plt.title('Pedestrian Involvement in Crashes by Hour of Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Pedestrians Involved')
plt.xticks(range(0, 24))
plt.grid()
plt.show()

# %% [markdown]
# #### **Analysis**
#
# The crashes peak at 8am and are higher during the later part of the day, especially between 4pm to 7pm in the evening, coinciding with rush hours.

# %% [markdown]
# ## 3. Insights

# %% [markdown]
# ### A. Borough-Wise Pedestrian Involvement
# - **Brooklyn**: Highest pedestrian crashes due to higher population density, large number of intersections, and greater urban activity.
# - **Staten Island**: Comparatively safer due to its smaller population, fewer intersections, and suburban characteristics.
# - **Disparities Among Boroughs**: Crash rates strongly correlate with population density, number of households, and intersection density.
#
# ---
#
# ### B. Ratio of Total Crashes to Pedestrian Involvement
# - Despite having the most crashes, **Brooklyn** shows a lower proportion of pedestrian involvement, suggesting better pedestrian safety measures like traffic calming and pedestrian infrastructure.
# - **Manhattan**: Higher pedestrian risk due to dense urban layout and high pedestrian activity, requiring targeted interventions for pedestrian safety.
# - **Staten Island**: Safest borough due to its lower population density and suburban environment.
#
# ---
#
# ### C. Top Contributing Factors to Pedestrian Crashes
# 1. **Driver-Related Factors**: Inattention, distraction, and failure to yield dominate causes, emphasizing the need for driver education and strict enforcement.
# 2. **Intersection Safety**: High risks at intersections due to "Failure to Yield Right-of-Way" and "Traffic Control Disregarded" highlight the importance of improved signaling, pedestrian crosswalk safety, and intersection redesign.
# 3. **Environmental Factors**: Situational risks like slippery pavement and close passing, though minor, should be addressed, especially in adverse weather.
# 4. **Driver Training**: Addressing inexperience and road rage through education and training programs is critical to improving pedestrian safety.
#
# ---
#
# ### D. Intersection vs. Non-Intersection Crashes
# - **Intersection Crashes**:
#   - Account for 77.5% of all crashes, making intersections high-risk zones requiring better safety measures like enhanced signaling, pedestrian crossings, and driver education to reduce confusion and conflicts.
# - **Non-Intersection Crashes**:
#   - While fewer (22.5%), they often occur in high-speed areas or due to jaywalking, necessitating targeted safety solutions for highways and undesignated crossing zones.
# - **Intersection Safety**: The high percentage of crashes at intersections underscores the need for prioritizing intersection safety measures.
#
# ---
#
# ### E. Time Series Analysis of Pedestrian Crashes by Hour of Day
# - Crashes peak during **morning (8 AM)** and **evening rush hours (4 PM–7 PM)**, aligning with high traffic and pedestrian activity.
# - **Time-Sensitive Risks**: Morning and evening rush hours require focused safety measures such as traffic management and heightened pedestrian awareness.

# %% [markdown]
# ## 4. Recommendations

# %% [markdown]
#  Recommendations for Improving Pedestrian Safety:
#
# ### A. For Pedestrians
# - **Use Designated Crosswalks**: Always cross at marked crosswalks and follow pedestrian signals.
# - **Avoid Distractions**: Refrain from using mobile phones or headphones while crossing streets.
# - **Stay Vigilant During Peak Hours**: Exercise extra caution during high-risk times (7–9 AM and 4–7 PM).
# - **Increase Visibility**: Wear reflective clothing, especially during evening hours.
# - **Advocate for Safer Infrastructure**: Participate in community efforts to demand better pedestrian-friendly infrastructure.
#
# ---
#
# ### B. For Drivers
# - **Eliminate Distractions**: Focus on the road and avoid using mobile phones while driving.
# - **Follow Yielding Rules**: Prioritize pedestrians, particularly at intersections and crosswalks.
# - **Reduce Speed in High-Pedestrian Zones**: Comply with reduced speed limits in crowded areas.
# - **Adhere to Traffic Rules**: Avoid running red lights or making unsafe turns.
# - **Driver Awareness Campaigns**: Encourage participation in training programs focused on pedestrian safety.
#
# ---
#
# ### C. For Transportation Professionals and City Planners
# - **Enhance Intersection Safety**:
#   - Install raised crosswalks, countdown signals, and better lighting.
#   - Implement "Leading Pedestrian Intervals" (LPIs) to give pedestrians a head start.
#   - Redesign high-crash intersections to reduce risks.
# - **Leverage Technology**:
#   - Use AI-driven real-time traffic monitoring systems and automated enforcement tools like red-light cameras.
#   - Provide navigation apps with alerts for high-risk intersections.
# - **Traffic Flow Optimization**:
#   - Adjust signal timing to reduce congestion in high-crash corridors.
#   - Implement traffic-calming measures such as speed humps and reduced speed zones near high-pedestrian areas.
# - **Promote Awareness**: Conduct campaigns to educate both drivers and pedestrians on road safety.
#
# ---
#
# ### D. For Law Enforcement and Policy Makers
# - **Stricter Penalties**: Enforce harsher penalties for violations like distracted driving and failure to yield at intersections.
# - **Incorporate Safety in Driver Training**: Include pedestrian safety in driving tests and renewals.
# - **Enforce Traffic Rules at Intersections**: Deploy red-light cameras and increase law enforcement presence at high-risk zones.
#
# ---
#
# ### E. For the General Public
# - **Support Safety Initiatives**: Advocate for programs like Vision Zero to reduce traffic-related fatalities.
# - **Report Unsafe Conditions**: Notify authorities about hazardous intersections or inadequate pedestrian facilities.
# - **Participate in Local Advocacy**: Join efforts to promote safer streets and improved pedestrian infrastructure.

# %% [markdown]
# ---

# %% [markdown]
# ## **Conclusion**
#
# This project involved analyzing NYC's motor vehicle collision data to understand pedestrian crash patterns across boroughs, intersections, and peak hours. The findings revealed that **Brooklyn has the highest number of crashes**, intersections account for **77.5% of pedestrian crashes**, and **driver inattention is a major contributing factor**. Time-based analysis showed that **crashes peak during morning and evening rush hours**. Based on these insights, recommendations were made for **intersection redesigns, stricter traffic enforcement, pedestrian safety campaigns, and technology-driven monitoring**. Implementing these measures can significantly enhance pedestrian safety in NYC.

# %% [markdown]
# ##<font color='crimson'>**Milestone #6 - Virtual Poster Board Creation: Data Storytelling**</font>
#
# GOAL: The main goal of this milestone is to create a one page, virtual poster board to portray your research findings and recommendations! Your poster may be shared with the Department of Transportation and Federal Highway Authority.

# %% [markdown]
# Within your poster, summarize your research question, your reasoning for selecting your data visualization or model choices, and key insights from your data analysis. You may also wish to include your outstanding research questions that could not be answered by the dataset and why.
#
# **Be sure to answer the following on your virtual poster board:** Based on your research insights, what recommendations would you share with the Department of Transportation and Federal Highway Authority to make roads safer for vulnerable road users? Why?
#
# **Additionally, be sure to cite all relevant sources that you referred to throughout this project on your poster board (MLA or APA citation preferred). List acknowlegdments if you received any support from mentors, professors, professionals, etc. throughout your journey.**

# %% [markdown]
#  Please use the following resources to get started!
#
#
# *   [Virtual Poster Board Template](https://nebigdatahub.org/wp-content/uploads/2024/01/Copy-of-dsi-poster.ppt-48-×-36-in.pdf) - Your one-page, virtual poster may be created in PowerPoint, Google Slides, Canva, etc. Choose what you are most comfortable with!
# * [ Data Storytelling: How to Effectively Tell a Story with Data](https://online.hbs.edu/blog/post/data-storytelling)
#
# * [  Consider how your visualization(s) might appear to people with varying abilities ](https://chartability.fizz.studio/)
# *  [Understand your audience for an optimal presentation](https://hbr.org/2013/04/how-to-tell-a-story-with-data)
#
#
# Once completed, please use the [following TDSP Submission Form](https://docs.google.com/forms/d/e/1FAIpQLSeX1OSHj58EQs4ypFEPB_SH3OpWZeo67yU0WWOPVSqYtDrpWg/viewform) to share your Google Colab Notebook and your one-page, virtual project poster with the NSDC HQ Team.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 🚗<font color='crimson'> **Thank you for completing the project!**</font> 🚗
#
# We are one step closer to making roads safer for all. [Please submit all materials to the NSDC HQ team](https://docs.google.com/forms/d/e/1FAIpQLSeX1OSHj58EQs4ypFEPB_SH3OpWZeo67yU0WWOPVSqYtDrpWg/viewform) in order to receive a certificate of completion. Do reach out to us if you have any questions or concerns. We are here to help you learn and grow.
